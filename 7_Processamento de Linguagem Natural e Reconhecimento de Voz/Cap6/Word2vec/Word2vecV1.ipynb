# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.9.7

# %%
# !nvidia-smi
# Out:
# Mon Aug  1 21:56:39 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 462.30       Driver Version: 462.30       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1650   WDDM  | 00000000:01:00.0  On |                  N/A |
# | N/A   37C    P8     1W /  N/A |    697MiB /  4096MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A       556    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A      1204    C+G   ...kyb3d8bbwe\Calculator.exe    N/A      |
# |    0   N/A  N/A      2980    C+G   ...lPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A      2992    C+G   ...8wekyb3d8bbwe\Cortana.exe    N/A      |
# |    0   N/A  N/A      3444    C+G   ...cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A      6152    C+G   ...wekyb3d8bbwe\Video.UI.exe    N/A      |
# |    0   N/A  N/A      7956    C+G   ...artMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A     10380    C+G   ...qxf38zg5c\Skype\Skype.exe    N/A      |
# |    0   N/A  N/A     11088    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     13996    C+G   ...ekyb3d8bbwe\YourPhone.exe    N/A      |
# |    0   N/A  N/A     14088    C+G   ...bbwe\Microsoft.Photos.exe    N/A      |
# |    0   N/A  N/A     19492    C+G   ...me\Application\chrome.exe    N/A      |
# |    0   N/A  N/A     19868    C+G   Insufficient Permissions        N/A      |
# |    0   N/A  N/A     20400    C+G   ...2txyewy\TextInputHost.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %%
# Imports
import os
import csv
import collections
import math
import random
import bz2
import nltk
import operator
import numpy as np
import tensorflow as tf
import matplotlib
import sklearn
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from math import ceil

# As novas versões do Pandas e Matplotlib trazem diversas mensagens de aviso ao desenvolvedor. Vamos desativar isso.
import sys
import warnings
import matplotlib.cbook
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=matplotlib.cbook.mplDeprecation)

# %matplotlib inline

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Rodrigo Abreu" --iversions
# Out:
# Author: Rodrigo Abreu
#
# tensorflow: 2.8.0
# sys       : 3.9.0 (default, Nov 15 2020, 08:30:55) [MSC v.1916 64 bit (AMD64)]
# numpy     : 1.22.3
# sklearn   : 0.0
# nltk      : 3.7
# csv       : 1.0
# matplotlib: 3.5.1

# %%
import tensorflow.python.util.deprecation as deprecation
deprecation._PRINT_DEPRECATION_WARNINGS = False
tf.compat.v1.disable_eager_execution()

# %% [markdown]
# ## Dataset
# Este código faz o download de um [conjunto de dados] (http://www.evanjones.ca/software/wikipedia2text.html) que consiste em vários artigos da Wikipedia, totalizando aproximadamente 61 MB. Além disso, o código garante que o arquivo tenha o tamanho correto após o download.

# %%
# Download do dataset
url = 'http://www.evanjones.ca/software/'

def maybe_download(filename, expected_bytes):
    """Faz o download de um arquivo, se não estiver presente, e verifica se ele está no tamanho certo."""
    if not os.path.exists(filename):
        print('Fazendo o download...')
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)

    if statinfo.st_size == expected_bytes:
        print('Encontrado e verificado: %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Não foi possível verificar ' + filename + '. Você consegue fazer o download com um navegador?')
    return filename

filename = 'C:/Users/Rodrigo/Documents/ProjetosDataScience/AtividadeFormacaoIA/7_Processamento de Linguagem Natural e Reconhecimento de Voz/Cap6/Word2vec/dados/wikipedia2text-extracted.txt'

# %% [markdown]
# ## Lendo os dados sem pré-processamento
# Leitura dos dados como string, tokeniza usando espaços e retorna uma lista de palavras.

# %%
def read_data(filename):
    """Extrai o primeiro arquivo contido no arquivo zip como uma lista de palavras"""

    with bz2.BZ2File(filename) as f:
        data = []
        file_string = f.read().decode('utf-8')
        file_string = nltk.word_tokenize(file_string)
        data.extend(file_string)
    return data

words = read_data(filename)
print('Número de palavras no dataset %d' % len(words))
print('Palavras de exemplo (start): ',words[:10])
print('Palavras de exemplo (end): ',words[-10:])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1944/2454507099.py in <module>
#       9     return data
#      10
# ---> 11 words = read_data(filename)
#      12 print('Número de palavras no dataset %d' % len(words))
#      13 print('Palavras de exemplo (start): ',words[:10])
#
# ~\AppData\Local\Temp/ipykernel_1944/2454507099.py in read_data(filename)
#       2     """Extrai o primeiro arquivo contido no arquivo zip como uma lista de palavras"""
#       3
# ----> 4     with bz2.BZ2File(filename) as f:
#       5         data = []
#       6         file_string = f.read().decode('utf-8')
#
# ~\anaconda3\envs\tf_gpu\lib\bz2.py in __init__(self, filename, mode, compresslevel)
#      83
#      84         if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 85             self._fp = _builtin_open(filename, mode)
#      86             self._closefp = True
#      87             self._mode = mode_code
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/Rodrigo/Documents/ProjetosDataScience/AtividadeFormacaoIA/7_Processamento de Linguagem Natural e Reconhecimento de Voz/Cap6/Word2vec/dados/wikipedia2text-extracted.txt'

# %% [markdown]
# ## Lendo os dados sem pré-processamento usando NLTK
# Leitura dos dados como string, converte em minúscula e converte em tokens usando a biblioteca nltk. Esse código lê os dados em partes de 1 MB, pois o processamento do texto completo seria muito lento, e então retorna uma lista de palavras. Você terá que baixar o tokenizer necessário.

# %%
def read_data(filename):
  """
  Extrai o primeiro arquivo contido em um arquivo zip como uma lista de palavras
  e pré-processa usando a biblioteca nltk python
  """

  with bz2.BZ2File(filename) as f:

    data = []
    file_size = os.stat(filename).st_size
    chunk_size = 1024 * 1024 # lendo 1 MB de cada vez, pois o conjunto de dados é moderadamente grande
    print('Lendo os dados...')
    for i in range(ceil(file_size//chunk_size)+1):
        bytes_to_read = min(chunk_size,file_size-(i*chunk_size))
        file_string = f.read(bytes_to_read).decode('utf-8')
        file_string = file_string.lower()

        # tokeniza uma string para palavras que residem em uma lista
        file_string = nltk.word_tokenize(file_string)
        data.extend(file_string)
    return data

words = read_data(filename)
print('Número de palavras no dataset %d' % len(words))
print('Palavras de exemplo (start): ',words[:10])
print('Palavras de exemplo (end): ',words[-10:])
# Out:
# Lendo os dados...
# Número de palavras no dataset 3361041
# Palavras de exemplo (start):  ['propaganda', 'is', 'a', 'concerted', 'set', 'of', 'messages', 'aimed', 'at', 'influencing']
# Palavras de exemplo (end):  ['favorable', 'long-term', 'outcomes', 'for', 'around', 'half', 'of', 'those', 'diagnosed', 'with']

# %% [markdown]
# ## Construindo os Dicionários
# Para entender cada um desses elementos, vamos também assumir o texto "Eu gosto de ir à escola"
#
# * `dictionary`: mapeia uma palavra para um ID (i.e. {Eu:0, gosto:1, de:2, ir:3, à:4, escola:5})
# * `reverse_dictionary`: mapeia um ID para uma palavra (i.e. {0:Eu, 1:gosto, 2:de, 3:ir, 4:à, 5:escola}
# * `count`: Lista de elementos (palavra, frequência) (i.e. [(Eu,1),(gosto,1),(de,2),(ir,1),(à,1),(escola,1)]
# * `data` : Contém a string de texto que lemos, onde palavras são substituídas por IDs de palavras (i.e. [0, 1, 2, 3, 2, 4])
#
# Também introduzimos um token especial adicional chamado `UNK` para indicar que palavras raras são muito raras para serem usadas.

# %%
# Nós restringimos o tamanho do nosso vocabulário para 50000
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]

    # Obtém apenas o vocabulary_size para palavras mais comuns como o vocabulário
    # Todas as outras palavras serão substituídas por token UNK
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()

    # Cria um ID para cada palavra, dando o comprimento atual do dicionário
    # e adicionando esse item ao dicionário
    for word, _ in count:
        dictionary[word] = len(dictionary)

    data = list()
    unk_count = 0

    # Percorrer todo o texto que temos e produzir uma lista onde cada elemento corresponde ao ID
    # da palavra encontrada nesse índice
    for word in words:
        # Se a palavra estiver no dicionário, use a palavra ID, senão use o ID do token especial "UNK"
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)

    # Atualiza a variável count com o número de ocorrências UNK
    count[0][1] = unk_count

    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))

    # Verifica se o dicionário é do tamanho do vocabulário
    assert len(dictionary) == vocabulary_size

    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Palavras mais comuns (+UNK)', count[:5])
print('Dados de amostra', data[:10])
del words
# Out:
# Palavras mais comuns (+UNK) [['UNK', 68859], ('the', 226892), (',', 184013), ('.', 120944), ('of', 116323)]
# Dados de amostra [1721, 9, 8, 16476, 223, 4, 5166, 4457, 26, 11592]

# %% [markdown]
# ## Gerando Lotes de Dados para o Skip-Gram
# Gera um lote ou palavras de destino (`batch`) e um lote de palavras de contexto correspondentes (`labels`). Ele lê as palavras `2 * window_size + 1` por vez (chamado` span`) e cria os datapoints `2 * window_size` em um único intervalo. A função continua dessa maneira até que os datapoints `batch_size` sejam criados. Toda vez que chegamos ao final da sequência de palavras, retornamos ao começo.

# %%
data_index = 0

def generate_batch_skip_gram(batch_size, window_size):
    # data_index é atualizado por 1 toda vez que lemos um ponto de dados
    global data_index

    # Dois arrays para conter as palavras-alvo (lote) e as palavras de contexto (etiquetas)
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)

    # span define o tamanho total da janela, onde os dados que consideramos em uma instância
    # são exibidos da seguinte maneira: [skip_window target skip_window]
    span = 2 * window_size + 1

    # O buffer contém os dados contidos no intervalo
    buffer = collections.deque(maxlen=span)

    # Preenche o buffer e atualiza o data_index
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    # Este é o número de palavras de contexto que experimentamos para uma única palavra de destino
    num_samples = 2 * window_size

    # Nós dividimos a leitura do lote em dois loops for
    # O loop interno preenche o lote e os rótulos com
    # num_samples pontos de dados usando dados contidos no intervalo
    # O loop externo é repetido por batch_size // num_samples times
    # para produzir um lote completo
    for i in range(batch_size // num_samples):
        k=0

        # Evita a própria palavra alvo como uma previsão
        # Preenchimento de matrizes de lotes e rótulos numpy
        for j in list(range(window_size))+list(range(window_size+1,2*window_size+1)):
            batch[i * num_samples + k] = buffer[window_size]
            labels[i * num_samples + k, 0] = buffer[j]
            k += 1

        # Toda vez que lemos num_samples pontos de dados,
        # criamos o número máximo de pontos de dados possíveis
        # com um único intervalo, por isso precisamos mover o span por 1
        # para criar um novo intervalo
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('Dados:', [reverse_dictionary[di] for di in data[:8]])

for window_size in [1, 2]:
    data_index = 0
    batch, labels = generate_batch_skip_gram(batch_size=8, window_size=window_size)
    print('\nCom window_size = %d:' %window_size)
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# Dados: ['propaganda', 'is', 'a', 'concerted', 'set', 'of', 'messages', 'aimed']
#
# Com window_size = 1:
#     batch: ['is', 'is', 'a', 'a', 'concerted', 'concerted', 'set', 'set']
#     labels: ['propaganda', 'a', 'is', 'concerted', 'a', 'set', 'concerted', 'of']
#
# Com window_size = 2:
#     batch: ['a', 'a', 'a', 'a', 'concerted', 'concerted', 'concerted', 'concerted']
#     labels: ['propaganda', 'is', 'concerted', 'set', 'is', 'a', 'set', 'of']

# %% [markdown]
# ## Algoritmo Skip-Gram

# %% [markdown]
# Com esse algoritmo vamos tentar prever o contexto dado a palavra de centro.
#
# - Observação =>  (wI , [wO1 , . . . ,wOC ])
# - Resultado => (cantor, [com, o, dessa, banda])
#
# Nesse modelo queremos minimizar a soma da entropia cruzada que é o mesmo que maximizar p(wo1 , . . . ,woC | wI ).

# %%
from IPython.display import Image
Image("images/skip.png")

# %%
from IPython.display import Image
Image("images/erro-skip.png")

# %% [markdown]
# ### Definindo Hiperparâmetros
#
# Aqui nós definimos vários hiperparâmetros incluindo
#
# - `batch_size` (quantidade de amostras em um único lote)
# - `embedding_size` (tamanho dos embedding vectors)
# - `window_size` (tamanho da janela de contexto).

# %%
# Pontos de dados em um único lote
batch_size = 128

# Dimensão do embedding vector.
embedding_size = 128

# Quantas palavras considerar à esquerda e à direita.
window_size = 4

# Nós escolhemos um conjunto de validação aleatório para testar os vizinhos mais próximos
# Conjunto aleatório de palavras para avaliar a similaridade.
valid_size = 16

# Nós experimentamos datapoints válidos aleatoriamente a partir de uma janela grande sem sermos sempre determinísticos
valid_window = 50

# Ao selecionar exemplos válidos, selecionamos algumas das palavras mais frequentes,
# bem como algumas palavras moderadamente raras
valid_examples = np.array(random.sample(range(valid_window), valid_size))
valid_examples = np.append(valid_examples,random.sample(range(1000, 1000+valid_window), valid_size),axis=0)

# Número de exemplos negativos para amostra.
num_sampled = 32

# %% [markdown]
# ### Definindo Entradas e Saídas
#
# Aqui nós definimos espaços reservados (placeholders) para alimentação dos dados de entrada e saída para o treinamento (cada um de tamanho `batch_size`) e um tensor constante para conter exemplos de validação.

# %%
tf.compat.v1.reset_default_graph()

# Dados de entrada de treinamento (IDs de palavras de destino).
train_dataset = tf.compat.v1.placeholder(tf.int32, shape=[batch_size])

# Dados de etiqueta de entrada de treinamento (IDs de palavras de contexto)
train_labels = tf.compat.v1.placeholder(tf.int32, shape=[batch_size, 1])

# Dados de entrada de validação, não precisamos de um espaço reservado,
# pois já definimos os IDs das palavras selecionadas como dados de validação
valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

# %% [markdown]
# ### Definindo Parâmetros do Modelo e Outras Variáveis
# Nós agora definimos diversas variáveis do TensorFlow, como uma camada embeddings (`embeddings`) e parâmetros de rede neural (`softmax_weights` e `softmax_biases`)

# %%
# Variáveis

# Embedding layer, contém as word embeddings
embeddings = tf.Variable(tf.random.uniform([vocabulary_size, embedding_size], -1.0, 1.0))

# Softmax Weights e Biases
softmax_weights = tf.Variable(
    tf.random.truncated_normal([vocabulary_size, embedding_size],
                        stddev=0.5 / math.sqrt(embedding_size)))

softmax_biases = tf.Variable(tf.random.uniform([vocabulary_size],0.0,0.01))

# %% [markdown]
# ### Definindo as Computações do Modelo
#
# Primeiro, definimos uma função de pesquisa para buscar os vetores embeddings correspondentes para um conjunto de entradas fornecidas. Com isso, definimos a função de perda negativa de amostragem `tf.nn.sampled_softmax_loss` que inclui os vetores embeddings e os parâmetros de rede neural previamente definidos.

# %%
# Modelo

# Procure por um lote de embeddings.
embed = tf.nn.embedding_lookup(params=embeddings, ids=train_dataset)

# Calcule a perda do softmax usando uma amostra dos rótulos negativos de cada vez.
loss = tf.reduce_mean(
    input_tensor=tf.nn.sampled_softmax_loss(
        weights = softmax_weights, biases = softmax_biases, inputs = embed,
        labels = train_labels, num_sampled = num_sampled, num_classes = vocabulary_size)
)

# %% [markdown]
# ### Calculando Similaridade de palavras
# Calculamos a similaridade entre duas palavras dadas em termos da distância do cosseno. Para fazer isso de maneira eficiente, usamos operações de matriz para fazer isso, conforme mostrado abaixo.

# %%
# Calcula a similaridade entre os exemplos de minibatch e todos os embeddings.
# Nós usamos a distância do cosseno:
norm = tf.sqrt(tf.reduce_sum(input_tensor=tf.square(embeddings), axis=1, keepdims=True))
normalized_embeddings = embeddings / norm
valid_embeddings = tf.nn.embedding_lookup(
params=normalized_embeddings, ids=valid_dataset)
similarity = tf.matmul(valid_embeddings, tf.transpose(a=normalized_embeddings))

# %% [markdown]
# ### Otimizador de Parâmetros do Modelo
#
# Em seguida, definimos uma taxa de aprendizado constante e um otimizador que usa o método Adagrad. Sinta-se à vontade para experimentar outros otimizadores listados [aqui] (https://www.tensorflow.org/api_guides/python/train).

# %%
# Otimizador
optimizer = tf.compat.v1.train.AdagradOptimizer(1.0).minimize(loss)

# %% [markdown]
# ## Treinando o Algoritmo Skip-Gram

# %%
num_steps = 100001
skip_losses = []

# ConfigProto é uma maneira de fornecer várias configurações necessárias para executar o grafo
with tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(allow_soft_placement=True)) as session:

    # Inicializa as variáveis no grafo
    tf.compat.v1.global_variables_initializer().run()
    print('Variáveis Inicializadas')
    average_loss = 0

    # Treina o modelo Word2vec para iterações num_step
    for step in range(num_steps):

        # Gera um único lote de dados
        batch_data, batch_labels = generate_batch_skip_gram(batch_size, window_size)

        # Preenche o feed_dict, executa o otimizador (minimize loss) e calcule a perda
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)

        # Atualiza a variável de perda média
        average_loss += l

        if (step+1) % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000

            skip_losses.append(average_loss)

            # A perda média é uma estimativa da perda nos últimos 2000 lotes.
            print('Erro Médio no Passo %d: %f' % (step+1, average_loss))
            average_loss = 0

        # Avaliação de simlaridade de palavras do conjunto de validação
        if (step+1) % 10000 == 0:
            sim = similarity.eval()

            # Aqui nós calculamos as palavras top_k mais próximas para uma dada palavra de validação
            # em termos da distância cosseno. Fazemos isso para todas as palavras no conjunto de validação.
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]

                # Número de vizinhos mais próximos
                top_k = 8
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Mais Próximo da palavra %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)

    skip_gram_final_embeddings = normalized_embeddings.eval()

# Vamos salvar os vetores de palavras aprendidos e a perda ao longo do tempo,
# pois essas informações são necessárias mais tarde para comparações
np.save('resultado/ski-pgram_embeddings', skip_gram_final_embeddings)

with open('resultado/skip-gram_losses.csv', 'wt') as f:
    writer = csv.writer(f, delimiter=',')
    writer.writerow(skip_losses)
# Out:
# Variáveis Inicializadas
# Erro Médio no Passo 2000: 3.997455
# Erro Médio no Passo 4000: 3.625232
# Erro Médio no Passo 6000: 3.575712
# Erro Médio no Passo 8000: 3.516207
# Erro Médio no Passo 10000: 3.489448
# Mais Próximo da palavra as: assassinating, historian, tsar, fia, quiet, lane, continuing, reuters,
# Mais Próximo da palavra from: in, and, clades, bees, non-partisan, naturalist, tenacity, constantinople,
# Mais Próximo da palavra ``: typing, bedroom, muhammed, fluoride, striatal, refuted, outbound, tcb,
# Mais Próximo da palavra been: 6000–5000, hi-tech, okina, macedon, mitochondrion, subjectivity, high-technology, 1086,
# Mais Próximo da palavra is: was, funding, are, bathtub, touch, stand-off, bowen, canards,
# Mais Próximo da palavra that: organizations, power-plant, affirms, made, two-dimensional, forbid, vociferously, publication,
# Mais Próximo da palavra had: selznick, wikiquote, experimenters, worthy, otara, compsognathids, clare, 1-1,
# Mais Próximo da palavra in: ,, ., the, from, and, of, i.e, by,
# Mais Próximo da palavra ;: shortened, falk, drawers, discordia, being, quiz, qu'ranic, monopolies,
# Mais Próximo da palavra .: ,, and, in, gilmour, by, airbases, commercialised, mc2,
# Mais Próximo da palavra not: farrakhan, 90,000, statue, disturbed, aziz, ship, relegate, stoic,
# Mais Próximo da palavra which: megalopolis, now-familiar, jill, bell-like, fatter, suspected, internationally-recognised, panama-pacific,
# Mais Próximo da palavra this: a, storm-force, franciscan, stemmed, 2030, constraints, shinto, 1697,
# Mais Próximo da palavra the: in, ,, hbsag, a, halloween, an, unfold, take-off,
# Mais Próximo da palavra ,: ., in, the, and, by, dialectic, jamaica, conurbations,
# Mais Próximo da palavra an: a, formal, eduskunta, the, ink, canoe, contradicts, pig,
# Erro Médio no Passo 12000: 3.433811
# Erro Médio no Passo 14000: 3.428494
# Erro Médio no Passo 16000: 3.395157
# Erro Médio no Passo 18000: 3.403548
# Erro Médio no Passo 20000: 3.395765
# Mais Próximo da palavra as: premixed, nme, eu, quevedo, osirian, awaiting, shootings, hugged,
# Mais Próximo da palavra from: ,, other, beers, éireann, by, blanchard, leviathan, ghanaian,
# Mais Próximo da palavra ``: refuted, simcoe, middlemen, '', faith, exam, typing, lavrenty,
# Mais Próximo da palavra been: banners, okina, mitochondrion, zebra, once, 1609, macedon, privileges,
# Mais Próximo da palavra is: was, has, 7.4, hadamard, jeanne, dobbins, noumenal, are,
# Mais Próximo da palavra that: it, which, he, 553, this, but, unbeknownst, sweats,
# Mais Próximo da palavra had: have, worthy, 1869, elephanta, has, maddadsson, was, time-honored,
# Mais Próximo da palavra in: ,, and, of, ., the, for, with, torinese,
# Mais Próximo da palavra ;: kilobit, stagnation, inhumane, shortened, :, sunburn, ., latter-day,
# Mais Próximo da palavra .: ,, of, and, in, the, by, rn, stagnation,
# Mais Próximo da palavra not: it, kinesin, 1948., that, put, botanica, say, braced,
# Mais Próximo da palavra which: but, that, who, morphology, 1453., popularised, shaka, equinoxes,
# Mais Próximo da palavra this: it, that, also, ubs, a, freiherr, 1758., secret,
# Mais Próximo da palavra the: ,, and, a, ., in, of, 77th, exclusions,
# Mais Próximo da palavra ,: and, ., in, the, langford, from, of, UNK,
# Mais Próximo da palavra an: a, slugging, ftp, the, formal, prerequisite, tswana, overcrowding,
# Erro Médio no Passo 22000: 3.341867
# Erro Médio no Passo 24000: 3.393015
# Erro Médio no Passo 26000: 3.351523
# Erro Médio no Passo 28000: 3.386061
# Erro Médio no Passo 30000: 3.373568
# Mais Próximo da palavra as: well, danto, behan, gripped, joan, imagists, also, persuaded,
# Mais Próximo da palavra from: gladys, blanchard, bismarck-schönhausen, greenberg, bees, lace, buteyko, inn,
# Mais Próximo da palavra ``: '', cladistic, particulate, żubrówka, flagging, :, hounslow, communicates,
# Mais Próximo da palavra been: okina, platz, low-altitude, zebra, bisects, once, denmark, noel,
# Mais Próximo da palavra is: was, are, attenuation, has, k.c, elusive, stains, invertebrates,
# Mais Próximo da palavra that: peada, it, this, hidden, hides, not, no, 3-by-0,
# Mais Próximo da palavra had: has, have, was, were, maddadsson, spring, goliath, worthy,
# Mais Próximo da palavra in: ,, of, and, promised, the, early, shanghe, prevailing,
# Mais Próximo da palavra ;: (, :, wesley, distinction, tübingen, if, fisker, 1853,
# Mais Próximo da palavra .: ,, sousley, on-base, entered, (, confines, mortality, hierarchy,
# Mais Próximo da palavra not: it, this, jōyō, they, that, but, be, 1948.,
# Mais Próximo da palavra which: modeled, puritanical, when, neuronal, cite, ubu, p.i.m.s, airfoil,
# Mais Próximo da palavra this: it, an, its, 's, a, not, that, anthracite,
# Mais Próximo da palavra the: 's, ,, a, of, mamluk, 559, eponym, in,
# Mais Próximo da palavra ,: in, ., the, of, 630s, padding, ndh, chemotherapy,
# Mais Próximo da palavra an: a, this, its, it, proof, celiac, cost, insufficient,
# Erro Médio no Passo 32000: 3.364199
# Erro Médio no Passo 34000: 3.331539
# Erro Médio no Passo 36000: 3.336563
# Erro Médio no Passo 38000: 3.343706
# Erro Médio no Passo 40000: 3.331932
# Mais Próximo da palavra as: flashing, decryption, sanctuary, behan, long-awaited, andesite, carthy, hypertensive,
# Mais Próximo da palavra from: into, bees, scapa, porphyry, underwent, pouring, mortimer, rotherhithe,
# Mais Próximo da palavra ``: '', ', :, flagging, compatriot, renovations, tommaso, american-owned,
# Mais Próximo da palavra been: bonaire, non-members, okina, many, become, nard, schleicher, also,
# Mais Próximo da palavra is: was, has, are, notwithstanding, 1869., shrines, elusive, yuriev,
# Mais Próximo da palavra that: if, have, sweats, not, idea, vociferously, preprint, but,
# Mais Próximo da palavra had: has, have, he, maddadsson, was, presumably, could, 1869,
# Mais Próximo da palavra in: ,, of, ., and, the, ataxia, diouf, hauer,
# Mais Próximo da palavra ;: :, wesley, fisker, tiff, ghanaian, |oct_rec_lo_°f, severed, anew,
# Mais Próximo da palavra .: ,, and, of, in, hosting, prescient, the, polkas,
# Mais Próximo da palavra not: it, they, seem, say, some, that, if, care,
# Mais Próximo da palavra which: :, puritanical, tsui, pga, when, necklace, where, forecaster,
# Mais Próximo da palavra this: its, it, o2, there, an, artwork, 1778, wry,
# Mais Próximo da palavra the: a, its, an, ,, 's, of, tco, and,
# Mais Próximo da palavra ,: ., and, of, in, the, UNK, taming, hoel,
# Mais Próximo da palavra an: its, the, a, this, empyema, katharine, spill, sp1,
# Erro Médio no Passo 42000: 3.334289
# Erro Médio no Passo 44000: 3.336904
# Erro Médio no Passo 46000: 3.346664
# Erro Médio no Passo 48000: 3.314778
# Erro Médio no Passo 50000: 3.308590
# Mais Próximo da palavra as: also, kean, objected, vaisheshika, deter, epstein-barr, decryption, behan,
# Mais Próximo da palavra from: into, while, and, porphyry, flow, wrap, walsh, through,
# Mais Próximo da palavra ``: lecture, bartok, triumphant, flagging, vestigial, refuted, ', compatriot,
# Mais Próximo da palavra been: bonaire, become, also, made, 540,000, since, okina, zebra,
# Mais Próximo da palavra is: was, are, has, midterm, became, k.c, 52,000, notwithstanding,
# Mais Próximo da palavra that: which, ., also, not, offered, when, securely, reactionary,
# Mais Próximo da palavra had: has, have, could, was, he, 1869, would, goalkeepers,
# Mais Próximo da palavra in: and, on, of, ngugi, inculcated, colonial-era, ethanol-rich, sideshow,
# Mais Próximo da palavra ;: :, wesley, magmatic, 475,000, agrippinensium, anew, lesseps, nears,
# Mais Próximo da palavra .: ,, and, that, coffeeshops, but, middle-aged, kapital, lott,
# Mais Próximo da palavra not: so, it, they, but, say, schizophrenic, could, 78.5,
# Mais Próximo da palavra which: that, nucleotides, by, who, j.p., but, 'law, also,
# Mais Próximo da palavra this: its, it, a, an, the, flipped, power-plant, postherpetic,
# Mais Próximo da palavra the: a, this, its, anak, china, hoover, reintroduced, bautista,
# Mais Próximo da palavra ,: ., and, sêla, handing, in, manzikert, scarce, woodall,
# Mais Próximo da palavra an: a, their, this, insufficient, mid-1980s, 1627, no, bernays,
# Erro Médio no Passo 52000: 3.290697
# Erro Médio no Passo 54000: 3.305696
# Erro Médio no Passo 56000: 3.312020
# Erro Médio no Passo 58000: 3.307511
# Erro Médio no Passo 60000: 3.309625
# Mais Próximo da palavra as: culturally, portrayed, ,, chattel, objected, behan, kean, alexa,
# Mais Próximo da palavra from: into, bujumbura, with, whispered, (, runners, lra, while,
# Mais Próximo da palavra ``: ), (, or, UNK, '', analyses, refuted, menshikov,
# Mais Próximo da palavra been: bonaire, become, okina, made, johnny, 540,000, temporal, zebra,
# Mais Próximo da palavra is: was, are, were, turkish-occupied, be, has, fifth-largest, dupont,
# Mais Próximo da palavra that: which, also, who, by, ;, marshallese, when, strathcona,
# Mais Próximo da palavra had: has, have, having, were, was, outnumber, lukewarm, spinks|decision,
# Mais Próximo da palavra in: of, early, the, throughout, during, ataxia, ,, harmony,
# Mais Próximo da palavra ;: ., :, ,, cadet, that, asean, phloem, by,
# Mais Próximo da palavra .: ;, ,, :, the, rmit, use, to, by,
# Mais Próximo da palavra not: so, it, say, 1948., that, if, they, transmission,
# Mais Próximo da palavra which: that, nauseating, written, raise, where, but, hadham, unlawfully,
# Mais Próximo da palavra this: it, its, a, the, there, yemenis, bibulus, although,
# Mais Próximo da palavra the: a, one, ,, this, ., in, 1705., litres,
# Mais Próximo da palavra ,: ., the, ;, (, churchills, accidentally, blowfish, by,
# Mais Próximo da palavra an: a, postage, sp1, 1970, ftp, katharine, the, 600s,
# Erro Médio no Passo 62000: 3.306634
# Erro Médio no Passo 64000: 3.315426
# Erro Médio no Passo 66000: 3.274198
# Erro Médio no Passo 68000: 3.276868
# Erro Médio no Passo 70000: 3.291870
# Mais Próximo da palavra as: isn, daza, merely, and, sanctuary, tragically, objected, b6,
# Mais Próximo da palavra from: into, leasehold, vectors, 930, helicopter, tiffany, coatings, alpaca,
# Mais Próximo da palavra ``: '', ), dwight, ,, my, UNK, ., menshikov,
# Mais Próximo da palavra been: bonaire, become, many, were, 540,000, i., since, kid,
# Mais Próximo da palavra is: was, are, omitting, 102,800, bowl, transformations, 125, can,
# Mais Próximo da palavra that: if, :, ., it, which, by, what, not,
# Mais Próximo da palavra had: have, has, could, would, was, were, warbler, but,
# Mais Próximo da palavra in: ,, on, and, modified, rushing, of, joke, 39/40,
# Mais Próximo da palavra ;: ., :, ,, la, crick, =32, morello, tattooing,
# Mais Próximo da palavra .: ,, ;, and, :, that, loarn, the, 's,
# Mais Próximo da palavra not: if, it, they, n't, that, say, but, searle,
# Mais Próximo da palavra which: but, that, by, ., :, who, nauseating, it,
# Mais Próximo da palavra this: it, a, 's, its, the, there, although, folded,
# Mais Próximo da palavra the: a, 's, his, ,, ., and, this, anti-statist,
# Mais Próximo da palavra ,: ., UNK, and, in, the, ;, dalai, ``,
# Mais Próximo da palavra an: a, postage, 1501, 1946, beats/min, this, 's, sp1,
# Erro Médio no Passo 72000: 3.286199
# Erro Médio no Passo 74000: 3.303905
# Erro Médio no Passo 76000: 3.294504
# Erro Médio no Passo 78000: 3.315921
# Erro Médio no Passo 80000: 3.278202
# Mais Próximo da palavra as: ,, smartphone, UNK, flavoured, ., was, repenomamus, wiseman,
# Mais Próximo da palavra from: into, vectors, spurt, \, simcity, destitute, between, unesco,
# Mais Próximo da palavra ``: '', or, called, meaning, companions, plus, gamblers, shoeshine,
# Mais Próximo da palavra been: bonaire, okina, since, become, multivac, many, 540,000, macedon,
# Mais Próximo da palavra is: was, are, became, bowl, name, 1874, were, notwithstanding,
# Mais Próximo da palavra that: which, if, what, also, it, ., be, so,
# Mais Próximo da palavra had: has, have, having, was, warbler, could, lukewarm, would,
# Mais Próximo da palavra in: of, dinner, hsbc, yamanaka, on, moreover, after, since,
# Mais Próximo da palavra ;: ., ,, when, put, where, nemo, vehemently, 1875.,
# Mais Próximo da palavra .: ,, ;, and, :, mules, that, as, of,
# Mais Próximo da palavra not: if, they, schizophrenic, so, n't, nfatc, sui, want,
# Mais Próximo da palavra which: that, but, namibia, vsevolod, carried, replied, speke, :,
# Mais Próximo da palavra this: it, also, there, geelong, however, another, a, the,
# Mais Próximo da palavra the: a, his, 's, and, ,, messenians, bautista, this,
# Mais Próximo da palavra ,: ., ;, with, and, as, UNK, celibacy, thoughtful,
# Mais Próximo da palavra an: a, marais, contradicts, distributions, sp1, gains, psychometric, amigas,
# Erro Médio no Passo 82000: 3.294790
# Erro Médio no Passo 84000: 3.293889
# Erro Médio no Passo 86000: 3.283365
# Erro Médio no Passo 88000: 3.279820
# Erro Médio no Passo 90000: 3.267268
# Mais Próximo da palavra as: poverty, epicurean, such, and, c.s, known, flavoured, stationed,
# Mais Próximo da palavra from: into, with, made, to, then, back, slide, up,
# Mais Próximo da palavra ``: '', scarcely, refuted, naïve, yoshihito, overheads, shackle, haldia,
# Mais Próximo da palavra been: become, bonaire, since, excel, zebra, multivac, tastes, i.,
# Mais Próximo da palavra is: was, are, became, omitting, were, has, engagements, geochemistry,
# Mais Próximo da palavra that: which, when, but, ., if, not, to, where,
# Mais Próximo da palavra had: have, has, was, were, having, warbler, m., colorful,
# Mais Próximo da palavra in: ,, of, and, the, during, for, on, .,
# Mais Próximo da palavra ;: :, brechin, where, ,, abdel, about, interchangeable, locative,
# Mais Próximo da palavra .: ,, and, that, the, in, 's, scheduling, bobcats,
# Mais Próximo da palavra not: if, they, but, so, although, when, detectors, only,
# Mais Próximo da palavra which: that, but, :, written, turbulent, essentialism, |dec_rec_hi_°f, cyclonic,
# Mais Próximo da palavra this: it, a, there, also, diminishing, instantly, now, the,
# Mais Próximo da palavra the: 's, a, his, and, in, ,, an, .,
# Mais Próximo da palavra ,: in, ., and, UNK, the, 's, youths, married,
# Mais Próximo da palavra an: a, the, carnivorous, devised, giza, attain, ernesto, crawling,
# Erro Médio no Passo 92000: 3.298541
# Erro Médio no Passo 94000: 3.265094
# Erro Médio no Passo 96000: 3.284251
# Erro Médio no Passo 98000: 3.277433
# Erro Médio no Passo 100000: 3.266223
# Mais Próximo da palavra as: bipolar, while, UNK, giles, loins, baronial, extraordinary, berchtesgaden,
# Mais Próximo da palavra from: and, in, of, walsh, through, then, their, porphyry,
# Mais Próximo da palavra ``: ?, you, gamblers, i, meaning, '', conseil, we,
# Mais Próximo da palavra been: bonaire, become, since, macedon, 540,000, some, trebia, huberman,
# Mais Próximo da palavra is: was, became, are, has, can, turkish-occupied, expansionary, bowl,
# Mais Próximo da palavra that: if, which, what, he, ., :, although, not,
# Mais Próximo da palavra had: has, have, were, was, by, could, he, 4-2,
# Mais Próximo da palavra in: ,, after, during, first, since, 's, of, at,
# Mais Próximo da palavra ;: ., :, only, hough, ,, but, alpert, mediocre,
# Mais Próximo da palavra .: ,, ;, and, the, 's, that, :, to,
# Mais Próximo da palavra not: if, so, they, no, it, that, schizophrenic, although,
# Mais Próximo da palavra which: that, where, translates, but, |dec_rec_hi_°f, controller, 51.8, ud,
# Mais Próximo da palavra this: a, also, an, it, secondly, the, however, involve,
# Mais Próximo da palavra the: a, 's, and, ,, ., UNK, another, of,
# Mais Próximo da palavra ,: ., and, UNK, in, the, 's, unspecified, for,
# Mais Próximo da palavra an: a, this, exceptional, atop, contradicts, blasting, sp1, gains,

# %% [markdown]
# ## Visualizando o Aprendizado do Algoritmo Skip-Gram

# %% [markdown]
# ### Encontrando apenas as palavras agrupadas

# %%
def find_clustered_embeddings(embeddings,distance_threshold,sample_threshold):
    '''
    Encontra apenas os agrupamentos próximos.
    Isso elimina os embeddings de palavra mais esparsamente distribuídos e torna a visualização mais clara.
    Isso é útil para a visualização de t-SNE.

    distance_threshold: distância máxima entre dois pontos para se qualificar como vizinhos
    sample_threshold: número de vizinhos requeridos para serem considerados um cluster
    '''

    # Calcular a similaridade de cosseno
    cosine_sim = np.dot(embeddings,np.transpose(embeddings))
    norm = np.dot(np.sum(embeddings**2,axis=1).reshape(-1,1),np.sum(np.transpose(embeddings)**2,axis=0).reshape(1,-1))
    assert cosine_sim.shape == norm.shape
    cosine_sim /= norm

    # Faz todas as entradas na diagonal zero; caso contrário, isso será escolhido como maior
    np.fill_diagonal(cosine_sim, -1.0)

    argmax_cos_sim = np.argmax(cosine_sim, axis=1)
    mod_cos_sim = cosine_sim

    # Encontra os máximos em um loop para contar se houver mais de n itens acima do limite
    for _ in range(sample_threshold-1):
        argmax_cos_sim = np.argmax(cosine_sim, axis=1)
        mod_cos_sim[np.arange(mod_cos_sim.shape[0]),argmax_cos_sim] = -1

    max_cosine_sim = np.max(mod_cos_sim,axis=1)

    return np.where(max_cosine_sim>distance_threshold)[0]

# %% [markdown]
# ### Computando a Visualização t-SNE de Word Embeddings Usando o Scikit-Learn

# %% [markdown]
# t-Distributed Stochastic Neighbor Embedding (t-SNE) é uma técnica (ganhadora de prêmios) para redução de dimensionalidade que é particularmente adequada para a visualização de conjuntos de dados de alta dimensão. A técnica pode ser implementada via aproximações do Barnes-Hut, permitindo que ela seja aplicada em grandes conjuntos de dados do mundo real.
#
# O t-SNE é uma ferramenta para visualizar dados de alta dimensão. Converte semelhanças entre pontos de dados para probabilidades conjuntas e tenta minimizar a divergência de Kullback-Leibler entre as probabilidades conjuntas da incorporação de baixa dimensão e os dados de alta dimensão. O t-SNE tem uma função de custo que não é convexa, ou seja, com diferentes inicializações, podemos obter resultados diferentes.
#
# É altamente recomendado usar outro método de redução de dimensionalidade (por exemplo, PCA para dados densos ou TruncatedSVD para dados esparsos) para reduzir o número de dimensões para uma quantidade razoável (por exemplo, 50) se o número de características for muito alto.

# %%
# Usaremos um grande espaço de amostra para construir o manfold T-SNE e, em seguida, 
# podá-lo usando semelhança de cosseno
num_points = 1000
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
print('Fitting embeddings no T-SNE. Isso pode levar um tempo ...')

# Obtém o T-SNE manifold
selected_embeddings = skip_gram_final_embeddings[:num_points, :]
two_d_embeddings = tsne.fit_transform(selected_embeddings)

# Poda os embeddings, obtendo apenas mais de n-muitos exemplos acima do limiar de similaridade
# Isto desobstrui a visualização
print('Pruning os T-SNE embeddings')
selected_ids = find_clustered_embeddings(selected_embeddings,.25,10)
two_d_embeddings = two_d_embeddings[selected_ids,:]

print('De um total de ', num_points, ' amostras, ', selected_ids.shape[0],' amostras foram selecionadas para pruning')
# Out:
# Fitting embeddings no T-SNE. Isso pode levar um tempo ...
# Pruning os T-SNE embeddings
# De um total de  1000  amostras,  386  amostras foram selecionadas para pruning

# %% [markdown]
# ### Plotar os Resultados do t-SNE com o Matplotlib

# %%
def plot(embeddings, labels):

    # Número de clusters
    n_clusters = 20

    # Constrói automaticamente um conjunto discreto de cores, cada uma para o cluster
    cmap = pylab.cm.get_cmap("Spectral")
    label_colors = [cmap(float(i) /n_clusters) for i in range(n_clusters)]

    assert embeddings.shape[0] >= len(labels), 'Mais rótulos do que embeddings'

    # Define K-Means
    kmeans = KMeans(n_clusters=n_clusters, init='k-means++', random_state=0).fit(embeddings)
    kmeans_labels = kmeans.labels_

    pylab.figure(figsize=(15,15))

    # Plot de todos os embeddings e suas palavras correspondentes
    for i, (label,klabel) in enumerate(zip(labels,kmeans_labels)):
        x, y = embeddings[i,:]
        pylab.scatter(x, y, c=label_colors[klabel])

        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom',fontsize=10)

    # Usar para salvar a figura, se necessário
    # pylab.savefig('word_embeddings.png')
    pylab.show()

words = [reverse_dictionary[i] for i in selected_ids]
plot(two_d_embeddings, words)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# # Algoritmo CBOW

# %% [markdown]
# Agora, partindo de uma janela arbitrária de tamanho C, vamos construir observações do tipo ([wI1 , . . . ,wIC ],wO).
#
# - Observação =>  ([wI1 , . . . ,wIC ], w0)
# - Resultado => ([com, o, dessa, banda], cantor)

# %% [markdown]
# Repetindo esse processo com diferentes exemplos extraídos do corpus o efeito vai acumular e como resultado palavras com contexto similar vão ficar próximas entre si. O que o modelo faz é capturar as estatísticas de co-ocorrência usando a distância cosseno.

# %%
from IPython.display import Image
Image("images/cbow.png")

# %% [markdown]
# ## Alterando o Processo de Geração de Dados
# Precisamos definir um novo gerador de dados para o CBOW. A forma da nova matriz de entrada é (batch_size, context_window * 2). Ou seja, um lote no CBOW captura todas as palavras no contexto de uma determinada palavra.

# %%
data_index = 0

def generate_batch_cbow(batch_size, window_size):
    # window_size é a quantidade de palavras que estamos vendo de cada lado de uma determinada palavra

    # data_index é atualizado por 1 toda vez que lemos um conjunto de dados
    global data_index

    # span define o tamanho total da janela, onde
    # dados que consideramos em uma instância são exibidos da seguinte maneira.
    # [skip_window target skip_window]
    # por exemplo, se skip_window = 2, em seguida, span = 5
    span = 2 * window_size + 1 # [ skip_window target skip_window ]

    # Dois arrays numpy para manter as palavras-alvo (lote)
    # e palavras de contexto (rótulos)
    # Observe que o lote tem colunas span-1 = 2 * window_size
    batch = np.ndarray(shape=(batch_size,span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)

    # O buffer contém os dados contidos no intervalo
    buffer = collections.deque(maxlen=span)

    # Preenche o buffer e atualize o data_index
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    # Aqui nós fazemos a leitura do lote
    # Nós iteramos através de cada índice de lote
    # Para cada índice de lote, iteramos pelos elementos de intervalo
    # para preencher as colunas da matriz de lotes
    for i in range(batch_size):

        # rótulo de destino no centro do buffer
        target = window_size

        # Só precisamos saber as palavras em torno de uma determinada palavra, não a palavra em si
        target_to_avoid = [ window_size ]

        # Adiciona o alvo selecionado para avoid_list da próxima vez
        col_idx = 0
        for j in range(span):

            # Ignora a palavra alvo ao criar o lote
            if j==span//2:
                continue
            batch[i,col_idx] = buffer[j]
            col_idx += 1
        labels[i, 0] = buffer[target]

        # Toda vez que lemos um ponto de dados,
        # precisamos mover o span por 1
        # para criar um novo intervalo
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    return batch, labels

for window_size in [1,2]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, window_size=window_size)
    print('\nCom window_size = %d:' % (window_size))
    print('    batch:', [[reverse_dictionary[bii] for bii in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# Com window_size = 1:
#     batch: [['propaganda', 'a'], ['is', 'concerted'], ['a', 'set'], ['concerted', 'of'], ['set', 'messages'], ['of', 'aimed'], ['messages', 'at'], ['aimed', 'influencing']]
#     labels: ['is', 'a', 'concerted', 'set', 'of', 'messages', 'aimed', 'at']
#
# Com window_size = 2:
#     batch: [['propaganda', 'is', 'concerted', 'set'], ['is', 'a', 'set', 'of'], ['a', 'concerted', 'of', 'messages'], ['concerted', 'set', 'messages', 'aimed'], ['set', 'of', 'aimed', 'at'], ['of', 'messages', 'at', 'influencing'], ['messages', 'aimed', 'influencing', 'the'], ['aimed', 'at', 'the', 'opinions']]
#     labels: ['a', 'concerted', 'set', 'of', 'messages', 'aimed', 'at', 'influencing']

# %% [markdown]
# ### Definindo os Hiperparâmetros
#
# Aqui nós definimos vários hiperparâmetros incluindo:
#
# - `batch_size` (quantidade de amostras em um único lote)
# - `embedding_size` (tamanho dos vetores embedding)
# - `window_size` (tamanho da janela de contexto).

# %%
# Pontos de dados em um único lote
batch_size = 128

# Dimensão do embedding vector.
embedding_size = 128

# Quantas palavras considerar à esquerda e à direita.
window_size = 2

# Nós escolhemos um conjunto de validação aleatório para testar os vizinhos mais próximos
# Conjunto aleatório de palavras para avaliar a similaridade.
valid_size = 16

# Nós experimentamos datapoints válidos aleatoriamente a partir de uma janela grande sem sermos sempre determinísticos
valid_window = 50

# Ao selecionar exemplos válidos, selecionamos algumas das palavras mais frequentes,
# bem como algumas palavras moderadamente raras
valid_examples = np.array(random.sample(range(valid_window), valid_size))
valid_examples = np.append(valid_examples,random.sample(range(1000, 1000+valid_window), valid_size),axis=0)

# Número de exemplos negativos para amostra.
num_sampled = 32

# %% [markdown]
# ### Definindo Entradas e Saídas
#
# Aqui nós definimos espaços reservados (placeholders) para alimentação dos dados de entrada e saída no treinamento (cada um dos tamanhos `batch_size`) e um tensor constante para conter exemplos de validação.

# %%
tf.compat.v1.reset_default_graph()

# Dados de entrada de treinamento (IDs de palavras de destino).
train_dataset = tf.compat.v1.placeholder(tf.int32, shape=[batch_size,2*window_size])

# Dados de etiqueta de entrada de treinamento (IDs de palavras de contexto)
train_labels = tf.compat.v1.placeholder(tf.int32, shape=[batch_size, 1])

# Dados de entrada de validação, não precisamos de um espaço reservado,
# pois já definimos os IDs das palavras selecionadas como dados de validação
valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

# %% [markdown]
# ### Definindo Parâmetros do Modelo e Outras Variáveis
# Nós agora definimos várias variáveis do TensorFlow, como uma camada embeddings (`embeddings`) e parâmetros de rede neural (`softmax_weights` e `softmax_biases`)

# %%
# Variáveis

# Embedding layer, contém as word embeddings
embeddings = tf.Variable(tf.random.uniform([vocabulary_size, embedding_size], -1.0, 1.0,dtype=tf.float32))

# Softmax Weights e Biases
softmax_weights = tf.Variable(tf.random.truncated_normal([vocabulary_size, embedding_size],
                 stddev=0.5 / math.sqrt(embedding_size),dtype=tf.float32))

softmax_biases = tf.Variable(tf.random.uniform([vocabulary_size],0.0,0.01))

# %% [markdown]
# ### Definindo as Computações do Modelo
#
# Primeiro, definimos uma função de pesquisa para buscar os vetores embedding correspondentes para um conjunto de entradas fornecidas. Concretamente, definimos pesquisas embedding de 2 $ x $ `window_size`. Em seguida, concatenamos todos esses vetores pesquisados para formar uma matriz de tamanho `[batch_size, embedding_size, 2 * window_size]`. Posteriormente, calculamos a média dessas pesquisas embedding para produzir um embedding médio de tamanho `[batch_size, embedding_size]`. Com isso, definimos a função de perda negativa de amostragem `tf.nn.sampled_softmax_loss` que inclui os vetores embedding e os parâmetros de rede neural previamente definidos.

# %%
# Modelo

# Aqui fazemos pesquisas de embedings para cada coluna no espaço reservado de entrada
# e, em seguida, calculamos a média para produzir um vetor de palavra embedding_size
stacked_embedings = None
print('Definindo %d embedding de pesquisas representando cada palavra no contexto'%(2*window_size))

for i in range(2*window_size):
    embedding_i = tf.nn.embedding_lookup(params=embeddings, ids=train_dataset[:,i])
    x_size,y_size = embedding_i.get_shape().as_list()
    if stacked_embedings is None:
        stacked_embedings = tf.reshape(embedding_i,[x_size,y_size,1])
    else:
        stacked_embedings = tf.concat(axis=2,values=[stacked_embedings,tf.reshape(embedding_i,[x_size,y_size,1])])

assert stacked_embedings.get_shape().as_list()[2]==2*window_size
print("Stacked embedding size: %s"%stacked_embedings.get_shape().as_list())

mean_embeddings =  tf.reduce_mean(input_tensor=stacked_embedings,axis=2,keepdims=False)
print("Reduced mean embedding size: %s"%mean_embeddings.get_shape().as_list())

# Calcula a perda do softmax usando uma amostra dos rótulos negativos de cada vez.
# entradas são embeddings das palavras do dataset de treino
# Com essa perda, otimizamos pesos, vieses, embeddings
loss = tf.reduce_mean(
    input_tensor=tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=mean_embeddings,
                           labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))
# Out:
# Definindo 4 embedding de pesquisas representando cada palavra no contexto
# Stacked embedding size: [128, 128, 4]
# Reduced mean embedding size: [128, 128]

# %% [markdown]
# ### Otimizador
#
# Em seguida, definimos uma taxa de aprendizado como uma constante e um otimizador que usa o método Adagrad. Sinta-se à vontade para experimentar outros otimizadores listados [aqui] (https://www.tensorflow.org/api_guides/python/train).

# %%
# Otimizador
optimizer = tf.compat.v1.train.AdagradOptimizer(1.0).minimize(loss)

# %% [markdown]
# ### Calculando similaridades de palavras
# Calculamos a similaridade entre duas palavras dadas em termos da distância do cosseno. Para fazer isso de maneira eficiente, usamos operações de matriz para fazer isso, conforme mostrado abaixo.

# %%
# Calcula a similaridade entre os exemplos de minibatch e todos os embeddings.
# Nós usamos a distância do cosseno:
norm = tf.sqrt(tf.reduce_sum(input_tensor=tf.square(embeddings), axis=1, keepdims=True))
normalized_embeddings = embeddings / norm
valid_embeddings = tf.nn.embedding_lookup(params=normalized_embeddings, ids=valid_dataset)
similarity = tf.matmul(valid_embeddings, tf.transpose(a=normalized_embeddings))

# %% [markdown]
# ## Treinando o Algoritmo CBOW

# %%
num_steps = 100001
cbow_losses = []

# ConfigProto é uma maneira de fornecer várias configurações necessárias para executar o grafo
with tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(allow_soft_placement=True)) as session:

    # Inicializa as variáveis no grafo
    tf.compat.v1.global_variables_initializer().run()
    print('Variáveis Inicializadas')

    average_loss = 0

    # Treina o modelo Word2vec para iterações num_step
    for step in range(num_steps):

        # Gera um único lote de dados
        batch_data, batch_labels = generate_batch_cbow(batch_size, window_size)

        # Preenche o feed_dict, executa o otimizador (minimize loss) e calcule a perda
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)

        # Atualiza a variável de perda média
        average_loss += l

        if (step+1) % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            cbow_losses.append(average_loss)
            print('Erro Médio no Passo %d: %f' % (step+1, average_loss))
            average_loss = 0

        # Avaliação de simlaridade de palavras do conjunto de validação
        if (step+1) % 10000 == 0:
            sim = similarity.eval()
            # Aqui nós calculamos as palavras top_k mais próximas para uma dada palavra de validação
            # em termos da distância cosseno. Fazemos isso para todas as palavras no conjunto de validação.
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Mais Próximo da palavra %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    cbow_final_embeddings = normalized_embeddings.eval()


np.save('resultado/cbow_embeddings', cbow_final_embeddings)

with open('resultado/cbow_losses.csv', 'wt') as f:
    writer = csv.writer(f, delimiter=',')
    writer.writerow(cbow_losses)
# Out:
# Variáveis Inicializadas
# Erro Médio no Passo 2000: 3.575102
# Erro Médio no Passo 4000: 3.072394
# Erro Médio no Passo 6000: 2.942249
# Erro Médio no Passo 8000: 2.867984
# Erro Médio no Passo 10000: 2.799851
# Mais Próximo da palavra are: were, is, 1498., pumping, hindustan, decides, rondeslottet, qui,
# Mais Próximo da palavra be: have, north-western, take, were, 12.1, lodging, blaine, tow,
# Mais Próximo da palavra which: but, mathematically, 1–3, who, that, tertiary, gower, counsellor,
# Mais Próximo da palavra was: is, became, were, had, featurettes, excommunicating, ecclesiastical, chaplain,
# Mais Próximo da palavra in: deflect, hasidic, lengthened, lance, during, albertosaurines, buckhead, blackfeet,
# Mais Próximo da palavra that: leonardo, which, luminous, dwindling, prosecuted, pend, hemings, heavenly,
# Mais Próximo da palavra has: had, have, is, bottle, funchal, became, angiosperm, tapered,
# Mais Próximo da palavra were: are, was, artefact, be, parma, outfielders, degenerates, gymnosperm,
# Mais Próximo da palavra (: percussive, lewis-clark, therapies, holly, championed, borer, nikolaevich, painters,
# Mais Próximo da palavra he: it, they, she, dispatch, navigational, oed1, allegations, ample,
# Mais Próximo da palavra '': rational, avalon, abortion-breast, marshals, converse, mr., ecce, top-seeded,
# Mais Próximo da palavra it: he, they, this, homeomorphism, there, sophomores, thus, 1790.,
# Mais Próximo da palavra .: ;, :, ,, signalled, pinprick, notches, advertised, w/m²,
# Mais Próximo da palavra one: collateral, prostitution, outflanking, 1406, 1618, command, middle-aged, handing,
# Mais Próximo da palavra ): everything2, either/or, payton, switchboard, anatolian, crepuscular, greedy, then-unknown,
# Mais Próximo da palavra for: ruth, sliding, gross-mind, summarised, thompson, hana, agnostic, g.w.s,
# Erro Médio no Passo 12000: 2.773051
# Erro Médio no Passo 14000: 2.721433
# Erro Médio no Passo 16000: 2.694195
# Erro Médio no Passo 18000: 2.680676
# Erro Médio no Passo 20000: 2.663482
# Mais Próximo da palavra are: were, is, pumping, 1498., hindustan, be, 38,575, boanta,
# Mais Próximo da palavra be: been, north-western, were, being, take, was, have, are,
# Mais Próximo da palavra which: but, who, mathematically, that, first-run, where, gower, 1–3,
# Mais Próximo da palavra was: is, became, were, featurettes, excommunicating, be, sutra, had,
# Mais Próximo da palavra in: throughout, during, since, lengthened, lance, deflect, 1865., blackfeet,
# Mais Próximo da palavra that: leonardo, which, hemings, heavenly, hadley, dwindling, neurone, re-examined,
# Mais Próximo da palavra has: had, have, is, bottle, 14-year-old, menapii, funchal, chipping,
# Mais Próximo da palavra were: are, was, artefact, be, have, 38,575, parma, litigious,
# Mais Próximo da palavra (: =, percussive, therapies, championed, painters, torch, holly, heed,
# Mais Próximo da palavra he: she, it, they, who, allegations, dispatch, depletion, navigational,
# Mais Próximo da palavra '': rational, abortion-breast, avalon, proscribed, happier, ecce, protruded, top-seeded,
# Mais Próximo da palavra it: he, this, she, they, there, thus, homeomorphism, 1790.,
# Mais Próximo da palavra .: ;, ,, :, advertised, pinprick, signalled, w/m², notches,
# Mais Próximo da palavra one: prostitution, middle-aged, 1618, command, 1406, objection, alerts, collateral,
# Mais Próximo da palavra ): everything2, payton, esthetical, textile, switchboard, crepuscular, either/or, anatolian,
# Mais Próximo da palavra for: ruth, sliding, artifice, ditches, summarised, clem, jigs, gross-mind,
# Erro Médio no Passo 22000: 2.621536
# Erro Médio no Passo 24000: 2.613387
# Erro Médio no Passo 26000: 2.586487
# Erro Médio no Passo 28000: 2.504418
# Erro Médio no Passo 30000: 2.442635
# Mais Próximo da palavra are: were, is, pumping, hindustan, 1498., have, include, buridan,
# Mais Próximo da palavra be: been, being, north-western, lead, were, 12.1, take, fordun,
# Mais Próximo da palavra which: but, where, who, that, mathematically, first-run, 1–3, virginian,
# Mais Próximo da palavra was: is, became, were, featurettes, sutra, beleaguered, been, had,
# Mais Próximo da palavra in: throughout, since, lengthened, lance, during, within, deflect, 1865.,
# Mais Próximo da palavra that: which, what, leonardo, hemings, heavenly, hadley, prosecuted, re-examined,
# Mais Próximo da palavra has: have, had, is, bottle, menapii, 14-year-old, perrache, funchal,
# Mais Próximo da palavra were: are, was, artefact, have, be, parma, 38,575, leninism,
# Mais Próximo da palavra (: =, percussive, torch, painters, mounting, holly, pears, therapies,
# Mais Próximo da palavra he: she, it, they, who, henin, dispatch, epr, ford,
# Mais Próximo da palavra '': happier, abortion-breast, dissected, ecce, rational, proscribed, avalon, called,
# Mais Próximo da palavra it: he, she, this, they, there, thus, homeomorphism, disliking,
# Mais Próximo da palavra .: ;, :, ,, advertised, w/m², slant, 2012., pinprick,
# Mais Próximo da palavra one: alerts, 1406, middle-aged, objection, prostitution, command, collateral, wing-mounted,
# Mais Próximo da palavra ): everything2, payton, anatolian, esthetical, switchboard, textile, twofold, taxation,
# Mais Próximo da palavra for: sliding, ruth, artifice, clem, ditches, jigs, summarised, mega,
# Erro Médio no Passo 32000: 2.445197
# Erro Médio no Passo 34000: 2.431865
# Erro Médio no Passo 36000: 2.417090
# Erro Médio no Passo 38000: 2.379509
# Erro Médio no Passo 40000: 2.399233
# Mais Próximo da palavra are: were, is, pumping, hindustan, 1498., include, buridan, matilda,
# Mais Próximo da palavra be: being, been, north-western, lead, fordun, 12.1, blaine, have,
# Mais Próximo da palavra which: but, where, who, first-run, particularly, mathematically, virginian, that,
# Mais Próximo da palavra was: is, became, were, has, had, rubens, sutra, been,
# Mais Próximo da palavra in: during, since, throughout, until, blackfeet, lance, lengthened, within,
# Mais Próximo da palavra that: what, which, hemings, re-examined, hadley, arrondissements, leonardo, heavenly,
# Mais Próximo da palavra has: have, had, is, bottle, 14-year-old, menapii, perrache, funchal,
# Mais Próximo da palavra were: are, was, artefact, 38,575, leninism, be, goblin, parma,
# Mais Próximo da palavra (: painters, championed, torch, percussive, holly, heed, =, mounting,
# Mais Próximo da palavra he: she, it, they, henin, epr, ironically, who, depletion,
# Mais Próximo da palavra '': dissected, abortion-breast, avalon, happier, ecosystems, polypeptide, mid-air, proscribed,
# Mais Próximo da palavra it: he, she, this, thus, there, they, 1-3, homeomorphism,
# Mais Próximo da palavra .: ;, 2012., ,, w/m², :, pinprick, signalled, lisboa,
# Mais Próximo da palavra one: alerts, middle-aged, objection, fielding, prostitution, 1406, 1618, collateral,
# Mais Próximo da palavra ): everything2, payton, textile, esthetical, crepuscular, twofold, taxation, switchboard,
# Mais Próximo da palavra for: sliding, ruth, artifice, mega, halftime, vetoing, jigs, peaches,
# Erro Médio no Passo 42000: 2.365157
# Erro Médio no Passo 44000: 2.378784
# Erro Médio no Passo 46000: 2.368730
# Erro Médio no Passo 48000: 2.352290
# Erro Médio no Passo 50000: 2.378517
# Mais Próximo da palavra are: were, is, pumping, include, 1498., hindustan, 38,575, being,
# Mais Próximo da palavra be: being, been, lead, north-western, was, were, fordun, are,
# Mais Próximo da palavra which: but, where, who, first-run, that, mathematically, virginian, particularly,
# Mais Próximo da palavra was: is, became, were, be, featurettes, been, wordless, sutra,
# Mais Próximo da palavra in: since, throughout, within, until, blackfeet, during, lengthened, documentary,
# Mais Próximo da palavra that: what, which, hemings, leonardo, low-growing, prosecuted, misuse, heavenly,
# Mais Próximo da palavra has: have, had, is, bottle, having, 14-year-old, menapii, includes,
# Mais Próximo da palavra were: are, was, artefact, 38,575, be, leninism, litigious, parma,
# Mais Próximo da palavra (: percussive, painters, championed, holly, heed, therapies, mounting, torch,
# Mais Próximo da palavra he: she, they, it, henin, ford, epr, later, ironically,
# Mais Próximo da palavra '': happier, dissected, abortion-breast, vissi, protruded, heirs, ecce, avalon,
# Mais Próximo da palavra it: he, she, this, thus, there, they, vasilevsky, landless,
# Mais Próximo da palavra .: ;, ,, :, advertised, 2012., sidereal, slant, pinprick,
# Mais Próximo da palavra one: alerts, wing-mounted, middle-aged, objection, unaware, fielding, 1406, inner-ring,
# Mais Próximo da palavra ): everything2, payton, esthetical, textile, anatolian, naturalism, crepuscular, twofold,
# Mais Próximo da palavra for: sliding, artifice, ditches, summarised, mega, vetoing, jigs, susa,
# Erro Médio no Passo 52000: 2.319156
# Erro Médio no Passo 54000: 2.283667
# Erro Médio no Passo 56000: 2.256579
# Erro Médio no Passo 58000: 2.243081
# Erro Médio no Passo 60000: 2.235392
# Mais Próximo da palavra are: were, is, hindustan, pumping, 1498., include, republiky, buridan,
# Mais Próximo da palavra be: being, been, north-western, lead, fordun, blaine, were, have,
# Mais Próximo da palavra which: where, but, virginian, who, first-run, whose, that, particularly,
# Mais Próximo da palavra was: is, became, were, had, wordless, been, chaplain, rubens,
# Mais Próximo da palavra in: throughout, since, lengthened, within, until, during, blackfeet, deflect,
# Mais Próximo da palavra that: what, which, hemings, hadley, neurone, leonardo, heavenly, pend,
# Mais Próximo da palavra has: have, had, is, having, bottle, menapii, includes, exceeding,
# Mais Próximo da palavra were: are, was, artefact, leninism, be, 38,575, gianni, parma,
# Mais Próximo da palavra (: painters, holly, heed, championed, mounting, torch, =, huts,
# Mais Próximo da palavra he: she, they, it, henin, epr, churchill, ford, ironically,
# Mais Próximo da palavra '': abortion-breast, dissected, happier, vissi, converse, avalon, rational, heirs,
# Mais Próximo da palavra it: he, she, this, thus, vasilevsky, wound, they, officially,
# Mais Próximo da palavra .: ;, :, ,, w/m², notches, signalled, jubbada, advertised,
# Mais Próximo da palavra one: alerts, fielding, wing-mounted, unpopularity, middle-aged, persevered, unaware, objection,
# Mais Próximo da palavra ): everything2, payton, textile, taxation, twofold, crepuscular, plc, greedy,
# Mais Próximo da palavra for: sliding, jigs, mega, summarised, artifice, susa, personnel, ditches,
# Erro Médio no Passo 62000: 2.247707
# Erro Médio no Passo 64000: 2.201752
# Erro Médio no Passo 66000: 2.235332
# Erro Médio no Passo 68000: 2.199716
# Erro Médio no Passo 70000: 2.211384
# Mais Próximo da palavra are: were, is, hindustan, include, pumping, buridan, 1498., require,
# Mais Próximo da palavra be: being, been, lead, north-western, fordun, get, blaine, remain,
# Mais Próximo da palavra which: where, but, who, first-run, particularly, whose, virginian, counsellor,
# Mais Próximo da palavra was: is, became, were, been, excommunicating, becomes, be, rubens,
# Mais Próximo da palavra in: throughout, during, until, since, lengthened, blackfeet, within, 0.8,
# Mais Próximo da palavra that: what, hemings, which, heavenly, misuse, re-examined, pend, 1305,
# Mais Próximo da palavra has: have, had, is, having, includes, bottle, menapii, 14-year-old,
# Mais Próximo da palavra were: are, was, artefact, 38,575, leninism, gianni, be, adding,
# Mais Próximo da palavra (: painters, holly, torch, championed, mounting, percussive, therapies, huts,
# Mais Próximo da palavra he: she, they, it, henin, epr, churchill, ford, ironically,
# Mais Próximo da palavra '': vissi, dissected, happier, abortion-breast, secretion, avalon, heirs, ecce,
# Mais Próximo da palavra it: she, he, vasilevsky, this, there, thus, landless, officially,
# Mais Próximo da palavra .: ;, wi-fi, lisboa, sidereal, 2012., ,, centrifugal-flow, :,
# Mais Próximo da palavra one: alerts, wing-mounted, fielding, objection, middle-aged, deployment, unpopularity, nero,
# Mais Próximo da palavra ): everything2, taxation, crepuscular, payton, 82, textile, esthetical, twofold,
# Mais Próximo da palavra for: sliding, artifice, mega, ditches, summarised, susa, vetoing, uncomfortable,
# Erro Médio no Passo 72000: 2.212190
# Erro Médio no Passo 74000: 2.192740
# Erro Médio no Passo 76000: 2.236539
# Erro Médio no Passo 78000: 2.174914
# Erro Médio no Passo 80000: 2.122686
# Mais Próximo da palavra are: were, is, hindustan, pumping, 1498., include, republiky, dragonfly,
# Mais Próximo da palavra be: being, been, north-western, lead, fordun, fly, get, remain,
# Mais Próximo da palavra which: where, but, first-run, who, whose, whom, virginian, burying,
# Mais Próximo da palavra was: is, became, were, becomes, been, sutra, rubens, featurettes,
# Mais Próximo da palavra in: throughout, since, during, within, documentary, until, third-fastest, blackfeet,
# Mais Próximo da palavra that: what, hemings, heavenly, which, misuse, hadley, leonardo, how,
# Mais Próximo da palavra has: have, had, is, includes, having, bottle, menapii, exceeding,
# Mais Próximo da palavra were: are, was, artefact, leninism, 38,575, inductive, gianni, parma,
# Mais Próximo da palavra (: painters, percussive, mounting, holly, championed, heed, torch, reciprocity,
# Mais Próximo da palavra he: she, they, it, henin, churchill, ford, epr, ironically,
# Mais Próximo da palavra '': abortion-breast, vissi, happier, dissected, ecce, secretion, literally, converse,
# Mais Próximo da palavra it: she, he, this, vasilevsky, officially, thus, henin, wound,
# Mais Próximo da palavra .: ;, slant, :, 2005., advertised, sidereal, w/m², 2012.,
# Mais Próximo da palavra one: alerts, wing-mounted, unpopularity, fielding, deployment, middle-aged, objection, inner-ring,
# Mais Próximo da palavra ): payton, everything2, crepuscular, textile, twofold, anatolian, esthetical, 82,
# Mais Próximo da palavra for: sliding, artifice, mega, ditches, susa, summarised, 1068, personnel,
# Erro Médio no Passo 82000: 2.139574
# Erro Médio no Passo 84000: 2.120394
# Erro Médio no Passo 86000: 2.115493
# Erro Médio no Passo 88000: 2.096198
# Erro Médio no Passo 90000: 2.100153
# Mais Próximo da palavra are: were, is, 1498., hindustan, pumping, republiky, include, individualist,
# Mais Próximo da palavra be: being, been, lead, north-western, remain, fordun, fly, blaine,
# Mais Próximo da palavra which: where, but, whom, first-run, whose, burying, particularly, litigants,
# Mais Próximo da palavra was: is, became, were, becomes, rubens, chaplain, sutra, been,
# Mais Próximo da palavra in: throughout, since, until, within, lengthened, during, lance, blackfeet,
# Mais Próximo da palavra that: what, hemings, how, misuse, hadley, neurone, re-examined, arrondissements,
# Mais Próximo da palavra has: have, had, is, having, includes, bottle, menapii, 14-year-old,
# Mais Próximo da palavra were: are, was, artefact, leninism, 38,575, parma, gianni, inductive,
# Mais Próximo da palavra (: holly, painters, fricatives, torch, championed, mounting, heed, percussive,
# Mais Próximo da palavra he: she, they, it, henin, churchill, epr, ford, oppenheimer,
# Mais Próximo da palavra '': dissected, abortion-breast, vissi, secretion, ecce, converse, avalon, cottage,
# Mais Próximo da palavra it: he, she, vasilevsky, bismarck, this, patel, epaminondas, thus,
# Mais Próximo da palavra .: ;, ,, w/m², slant, advertised, 2012., wi-fi, bless,
# Mais Próximo da palavra one: deployment, fielding, wing-mounted, alerts, middle-aged, unpopularity, inner-ring, objection,
# Mais Próximo da palavra ): everything2, crepuscular, payton, twofold, textile, plc, either/or, astana,
# Mais Próximo da palavra for: sliding, mega, vetoing, personnel, ditches, jigs, 1068, artifice,
# Erro Médio no Passo 92000: 2.096390
# Erro Médio no Passo 94000: 2.092394
# Erro Médio no Passo 96000: 2.108819
# Erro Médio no Passo 98000: 2.097591
# Erro Médio no Passo 100000: 2.103219
# Mais Próximo da palavra are: were, is, 1498., include, hindustan, pumping, republiky, dragonfly,
# Mais Próximo da palavra be: being, been, lead, north-western, remain, fly, get, fordun,
# Mais Próximo da palavra which: where, but, whom, whose, first-run, litigants, who, counsellor,
# Mais Próximo da palavra was: is, became, were, becomes, rubens, remains, been, performs,
# Mais Próximo da palavra in: throughout, until, within, blackfeet, documentary, during, exponential, since,
# Mais Próximo da palavra that: what, hemings, how, which, pend, misuse, hadley, neurone,
# Mais Próximo da palavra has: have, had, includes, having, is, bottle, 14-year-old, menapii,
# Mais Próximo da palavra were: are, was, artefact, 38,575, leninism, gianni, litigious, inductive,
# Mais Próximo da palavra (: holly, heed, painters, championed, umbanda, percussive, fricatives, mounting,
# Mais Próximo da palavra he: she, they, henin, churchill, it, epr, ford, ironically,
# Mais Próximo da palavra '': vissi, abortion-breast, dissected, secretion, converse, literally, happier, forelimbs,
# Mais Próximo da palavra it: she, he, vasilevsky, this, officially, epaminondas, bismarck, thus,
# Mais Próximo da palavra .: ;, 2012., ,, sidereal, advertised, centrifugal-flow, 2006., wi-fi,
# Mais Próximo da palavra one: wing-mounted, alerts, fielding, inner-ring, unpopularity, nero, unaware, deployment,
# Mais Próximo da palavra ): payton, everything2, textile, astana, crepuscular, either/or, anatolian, naturalism,
# Mais Próximo da palavra for: sliding, ditches, mega, personnel, artifice, susa, peaches, wilhelmine,

# %% [markdown]
# # Fim
